# %%
import tweepy as tp
import pandas as pd
import numpy as np
import re
import nltk
import gensim
import random
import pickle
from datetime import datetime, date, time, timedelta
from keras.models import Model
# Out:
# Using TensorFlow backend.

# %%
tweets = []
with open ('Fashion_12K_tweets', 'rb') as fp:
    tweets = pickle.load(fp)

# %%
def remove_emoji(string):
    emoji_pattern = re.compile("["
                           u"\U0001F600-\U0001F64F"  # emoticons
                           u"\U0001F300-\U0001F5FF"  # symbols & pictographs
                           u"\U0001F680-\U0001F6FF"  # transport & map symbols
                           u"\U0001F1E0-\U0001F1FF"  # flags (iOS)
                           u"\U00002702-\U000027B0"
                           u"\U000024C2-\U0001F251"
                           "]+", flags=re.UNICODE)
    return emoji_pattern.sub(r'', string)

# %%
tweetSeries = pd.Series(tweets).str.replace(r'\B(\@[ 0-9a-zA-Z_]+\b)(?!;)', "%%USER%%").str.replace(r'\s\s+', " ")
noHashtag = tweetSeries.str.replace(r'\B(\#[ 0-9a-zA-Z_]+\b)(?!;)', "%%HASHTAG%%").str.replace(r'\s\s+', " ")
noPunc = noHashtag.str.replace(r'[.,?!:;<>_\(\)\[\]\{\}\+\=\@\#\$\%\^\|\*\'\"]', "").str.replace(r'[-_—0-9]', " ").apply(remove_emoji)
sentList = noPunc.str.replace(" USER", "").str.replace(" HASHTAG", "").str.lower().str.split()
spacePunc = noHashtag.str.replace(r"([\w/'+$\s-]+|[^\w/'+$\s-]+)\s*", r"\1 ")
tweetDF = tweetSeries.to_frame("Baseline")
tweetDF["Space B/W Punc"] = spacePunc
tweetDF["List of Words + Punc"] = spacePunc.str.split()
tweetDF["Baseline + No HashTags"] = noHashtag
tweetDF["Baseline + No HashTags + No Punc"] = noPunc
tweetDF["List of Words"] = sentList
tweetDF["Part-of-Speech"] = tweetDF["List of Words"].apply(nltk.pos_tag)
tweetDF
# Out:
#                                                 Baseline  \
# 0      The always-on Icon denim jacket, now in new wa...
# 1      Our softest sweats ever. An easy vintage vibe ...
# 2      Layer on a sweatshirt and a wear-everywhere Ic...
# 3      Yes, you can wear white denim year-round! Our ...
# 4      How to take your denim game to the next level:...
# 5      Universally flattering high waist. Made to hit...
# 6      Borrowed from the boys. Here’s how to wear our...
# 7      Work to weekend to whatever you've got going o...
# 8      This is our bestselling Slim, in new authentic...
# 9      What's your favorite way to wear #GapDenim: li...
# 10     New Authentic Vintage. Washes inspired by our ...
# 11     Our soft Valentine’s Day tee and Stretch Cotto...
# 12     "Real love starts with self-love." - %%USER%%,...
# 13     We LOVE writer, wife, mother, and host of #The...
# 14     From the classic Straight to bestselling High ...
# 15     Fits for all. Washes the way you like them. Je...
# 16     We make great jeans. You make them yours. Get ...
# 17     Your GAP ACT was 💯, Amy! We’d buy t-shirts fro...
# 18     The best sports bras by any stretch. Find your...
# 19     For all the ways you lounge, move, live. Get i...
# 20     Whether you're hitting the fitness studio or t...
# 21     Make your move in high rise leggings with Scul...
# 22     Start the year off right with the best legging...
# 23     Fits for every body and all the ways you move....
# 24     Sale. Ends. Soon. Don’t miss out on up to 75% ...
# 25     The Great Gap Sale continues! Get up to 75% of...
# 26     It’s our biggest sale of the year! Shop now &a...
# 27     Got last-minute gifts to buy? We’ve got you! G...
# 28     Give them what they want. Give GiftCards (in s...
# 29     Last call for great gifts for all! Shop by 3 p...
# ...                                                  ...
# 13145  vintage throwback tees are back &amp; we've ad...
# 13146  pick your fave for only $8! http://t.co/s9wttf...
# 13147  how #PLL should have ended... 😂 http://t.co/zh...
# 13148  have a student ID? show in store to get 10% of...
# 13149  the perfect back to school polos are now only ...
# 13150  top bun kinda day. http://t.co/vpUQQMigZg http...
# 13152  polo perfection . get them now for only $11 . ...
# 13153  ready for cozy fall days . 🍂 http : //t . co/A...
# 13154  loving  %% USER %%! find them in store  & amp ...
# 13155  class it up . vintage-cut throwback polos are ...
# 13156  back to school ready in the perfect polo . htt...
# 13157  when nobody responds to you in the group chat ...
# 13158  nature girl . http : //t . co/I07PuNl76g http ...
# 13159  new arrivals are in store  & amp ; online toda...
# 13160  while supplies last : get a free beanie with a...
# 13161  find your perfect polo for only $8 ! http : //...
# 13162  our cozy waffle henleys are now only $12 ! htt...
# 13163  saturday night out in our fave  %% USER %%! ht...
# 13164  big city dreams . http : //t . co/K2ikCOZHRL h...
# 13165  layer up in the perfect baseball tee . find th...
# 13166  buy any seriously stretchy denim this weekend ...
# 13167  meet our newest obsession  %% HASHTAG %%. clic...
# 13168  score our fave layering tees for only $12 ! cl...
# 13169  when you eat too much dinner ... http : //t . ...
# 13170  seriously soft . seriously stretchy . seriousl...
# 13171  friday vibes in the  %% HASHTAG %%. http : //t...
# 13172  it's here : shop the newest  %% HASHTAG %%! ht...
# 13173  get the perfect layering tee for only $12 ! ht...
# 13174  thursday jewels . 💎 http : //t . co/XZiuQgSivd...
#
#                                     List of Words + Punc  \
# 0      [The, always-on, Icon, denim, jacket, ,, now, ...
# 1      [Our, softest, sweats, ever, ., An, easy, vint...
# 2      [Layer, on, a, sweatshirt, and, a, wear-everyw...
# 3      [Yes, ,, you, can, wear, white, denim, year-ro...
# 4      [How, to, take, your, denim, game, to, the, ne...
# 5      [Universally, flattering, high, waist, ., Made...
# 6      [Borrowed, from, the, boys, ., Here, ’, s, how...
# 7      [Work, to, weekend, to, whatever, you've, got,...
# 8      [This, is, our, bestselling, Slim, ,, in, new,...
# 9      [What's, your, favorite, way, to, wear, %%, HA...
# 10     [New, Authentic, Vintage, ., Washes, inspired,...
# 11     [Our, soft, Valentine, ’, s, Day, tee, and, St...
# 12     [", Real, love, starts, with, self-love, .", -...
# 13     [We, LOVE, writer, ,, wife, ,, mother, ,, and,...
# 14     [From, the, classic, Straight, to, bestselling...
# 15     [Fits, for, all, ., Washes, the, way, you, lik...
# 16     [We, make, great, jeans, ., You, make, them, y...
# 17     [Your, GAP, ACT, was, 💯,, Amy, !, We, ’, d, bu...
# 18     [The, best, sports, bras, by, any, stretch, .,...
# 19     [For, all, the, ways, you, lounge, ,, move, ,,...
# 20     [Whether, you're, hitting, the, fitness, studi...
# 21     [Make, your, move, in, high, rise, leggings, w...
# 22     [Start, the, year, off, right, with, the, best...
# 23     [Fits, for, every, body, and, all, the, ways, ...
# 24     [Sale, ., Ends, ., Soon, ., Don, ’, t, miss, o...
# 25     [The, Great, Gap, Sale, continues, !, Get, up,...
# 26     [It, ’, s, our, biggest, sale, of, the, year, ...
# 27     [Got, last-minute, gifts, to, buy, ?, We, ’, v...
# 28     [Give, them, what, they, want, ., Give, GiftCa...
# 29     [Last, call, for, great, gifts, for, all, !, S...
# ...                                                  ...
# 13145  [vintage, throwback, tees, are, back, &, amp, ...
# 13146  [pick, your, fave, for, only, $8, !, http, :, ...
# 13147  [how, %%, HASHTAG, %%..., 😂, http, :, //t, ., ...
# 13148  [have, a, student, ID, ?, show, in, store, to,...
# 13149  [the, perfect, back, to, school, polos, are, n...
# 13150  [top, bun, kinda, day, ., http, :, //t, ., co/...
# 13151  [keeping, it, casual, ., http, :, //t, ., co/K...
# 13152  [polo, perfection, ., get, them, now, for, onl...
# 13153  [ready, for, cozy, fall, days, ., 🍂, http, :, ...
# 13154  [loving, %%, USER, %%!, find, them, in, store,...
# 13155  [class, it, up, ., vintage-cut, throwback, pol...
# 13156  [back, to, school, ready, in, the, perfect, po...
# 13157  [when, nobody, responds, to, you, in, the, gro...
# 13158  [nature, girl, ., http, :, //t, ., co/I07PuNl7...
# 13159  [new, arrivals, are, in, store, &, amp, ;, onl...
# 13160  [while, supplies, last, :, get, a, free, beani...
# 13161  [find, your, perfect, polo, for, only, $8, !, ...
# 13162  [our, cozy, waffle, henleys, are, now, only, $...
# 13163  [saturday, night, out, in, our, fave, %%, USER...
# 13164  [big, city, dreams, ., http, :, //t, ., co/K2i...
# 13165  [layer, up, in, the, perfect, baseball, tee, ....
# 13166  [buy, any, seriously, stretchy, denim, this, w...
# 13167  [meet, our, newest, obsession, %%, HASHTAG, %%...
# 13168  [score, our, fave, layering, tees, for, only, ...
# 13169  [when, you, eat, too, much, dinner, ..., http,...
# 13170  [seriously, soft, ., seriously, stretchy, ., s...
# 13171  [friday, vibes, in, the, %%, HASHTAG, %%., htt...
# 13172  [it's, here, :, shop, the, newest, %%, HASHTAG...
# 13173  [get, the, perfect, layering, tee, for, only, ...
# 13174  [thursday, jewels, ., 💎, http, :, //t, ., co/X...
#
#                                   Baseline + No HashTags  \
# 0      The always-on Icon denim jacket, now in new wa...
# 1      Our softest sweats ever. An easy vintage vibe ...
# 2      Layer on a sweatshirt and a wear-everywhere Ic...
# 3      Yes, you can wear white denim year-round! Our ...
# 4      How to take your denim game to the next level:...
# 5      Universally flattering high waist. Made to hit...
# 6      Borrowed from the boys. Here’s how to wear our...
# 7      Work to weekend to whatever you've got going o...
# 8      This is our bestselling Slim, in new authentic...
# 9      What's your favorite way to wear %%HASHTAG%%: ...
# 10     New Authentic Vintage. Washes inspired by our ...
# 11     Our soft Valentine’s Day tee and Stretch Cotto...
# 12     "Real love starts with self-love." - %%USER%%,...
# 13     We LOVE writer, wife, mother, and host of %%HA...
# 14     From the classic Straight to bestselling High ...
# 15     Fits for all. Washes the way you like them. Je...
# 16     We make great jeans. You make them yours. Get ...
# 17     Your GAP ACT was 💯, Amy! We’d buy t-shirts fro...
# 18     The best sports bras by any stretch. Find your...
# 19     For all the ways you lounge, move, live. Get i...
# 20     Whether you're hitting the fitness studio or t...
# 21     Make your move in high rise leggings with Scul...
# 22     Start the year off right with the best legging...
# 23     Fits for every body and all the ways you move....
# 24     Sale. Ends. Soon. Don’t miss out on up to 75% ...
# 25     The Great Gap Sale continues! Get up to 75% of...
# 26     It’s our biggest sale of the year! Shop now &a...
# 27     Got last-minute gifts to buy? We’ve got you! G...
# 28     Give them what they want. Give GiftCards (in s...
# 29     Last call for great gifts for all! Shop by 3 p...
# ...                                                  ...
# 13145  vintage throwback tees are back &amp; we've ad...
# 13149  the perfect back to school polos are now only ...
# 13150  top bun kinda day http//tco/vpUQQMigZg http//t...
# 13151  keeping it casual http//tco/K I CgySdm http//t...
# 13152  polo perfection get them now for only    http/...
# 13153  ready for cozy fall days  http//tco/A  ri bZV ...
# 13154  loving USER find them in store &amp online now...
# 13155  class it up vintage cut throwback polos are   ...
# 13156  back to school ready in the perfect polo http/...
# 13157  when nobody responds to you in the group chat ...
# 13158  nature girl http//tco/I  PuNl  g http//tco/Ee ...
# 13159  new arrivals are in store &amp online today ht...
# 13160  while supplies last get a free beanie with any...
# 13161  find your perfect polo for only   http//tco/JE...
# 13162  our cozy waffle henleys are now only    http//...
# 13163  saturday night out in our fave USER http//tco/...
# 13164  big city dreams http//tco/K ikCOZHRL http//tco...
# 13165  layer up in the perfect baseball tee find them...
# 13166  buy any seriously stretchy denim this weekend ...
# 13167  meet our newest obsession HASHTAG click to sho...
# 13168  score our fave layering tees for only    click...
# 13169  when you eat too much dinner http//tco/Dil V v OL
# 13170  seriously soft seriously stretchy seriously th...
# 13171  friday vibes in the HASHTAG http//tco/JuMvlQEG...
# 13172  its here shop the newest HASHTAG http//tco/iwB...
# 13173  get the perfect layering tee for only    http/...
# 13174  thursday jewels  http//tco/XZiuQgSivd http//tc...
#
#                                            List of Words  \
# 0      [the, always, on, icon, denim, jacket, now, in...
# 1      [our, softest, sweats, ever, an, easy, vintage...
# 2      [layer, on, a, sweatshirt, and, a, wear, every...
# 3      [yes, you, can, wear, white, denim, year, roun...
# 4      [how, to, take, your, denim, game, to, the, ne...
# 5      [universally, flattering, high, waist, made, t...
# 6      [borrowed, from, the, boys, here’s, how, to, w...
# 7      [work, to, weekend, to, whatever, youve, got, ...
# 8      [this, is, our, bestselling, slim, in, new, au...
# 9      [whats, your, favorite, way, to, wear, light, ...
# 10     [new, authentic, vintage, washes, inspired, by...
# 11     [our, soft, valentine’s, day, tee, and, stretc...
# 12     [real, love, starts, with, self, love, writer,...
# 13     [we, love, writer, wife, mother, and, host, of...
# 14     [from, the, classic, straight, to, bestselling...
# 15     [fits, for, all, washes, the, way, you, like, ...
# 16     [we, make, great, jeans, you, make, them, your...
# 17     [your, gap, act, was, amy, we’d, buy, t, shirt...
# 18     [the, best, sports, bras, by, any, stretch, fi...
# 19     [for, all, the, ways, you, lounge, move, live,...
# 20     [whether, youre, hitting, the, fitness, studio...
# 21     [make, your, move, in, high, rise, leggings, w...
# 22     [start, the, year, off, right, with, the, best...
# 23     [fits, for, every, body, and, all, the, ways, ...
# 24     [sale, ends, soon, don’t, miss, out, on, up, t...
# 25     [the, great, gap, sale, continues, get, up, to...
# 26     [it’s, our, biggest, sale, of, the, year, shop...
# 27     [got, last, minute, gifts, to, buy, we’ve, got...
# 28     [give, them, what, they, want, give, giftcards...
# 29     [last, call, for, great, gifts, for, all, shop...
# ...                                                  ...
# 13145  [vintage, throwback, tees, are, back, &amp, we...
# 13146  [pick, your, fave, for, only, http//tco/s, wtt...
# 13147                        [how, http//tco/zh, aewkyx]
# 13148  [have, a, student, id, show, in, store, to, ge...
# 13149  [the, perfect, back, to, school, polos, are, n...
# 13150  [top, bun, kinda, day, http//tco/vpuqqmigzg, h...
# 13151  [keeping, it, casual, http//tco/k, i, cgysdm, ...
# 13152  [polo, perfection, get, them, now, for, only, ...
# 13153  [ready, for, cozy, fall, days, http//tco/a, ri...
# 13154  [loving, find, them, in, store, &amp, online, ...
# 13155  [class, it, up, vintage, cut, throwback, polos...
# 13156  [back, to, school, ready, in, the, perfect, po...
# 13157  [when, nobody, responds, to, you, in, the, gro...
# 13158  [nature, girl, http//tco/i, punl, g, http//tco...
# 13159  [new, arrivals, are, in, store, &amp, online, ...
# 13160  [while, supplies, last, get, a, free, beanie, ...
# 13161  [find, your, perfect, polo, for, only, http//t...
# 13162  [our, cozy, waffle, henleys, are, now, only, h...
# 13163  [saturday, night, out, in, our, fave, http//tc...
# 13164  [big, city, dreams, http//tco/k, ikcozhrl, htt...
# 13165  [layer, up, in, the, perfect, baseball, tee, f...
# 13166  [buy, any, seriously, stretchy, denim, this, w...
# 13167  [meet, our, newest, obsession, click, to, shop...
# 13168  [score, our, fave, layering, tees, for, only, ...
# 13169  [when, you, eat, too, much, dinner, http//tco/...
# 13170  [seriously, soft, seriously, stretchy, serious...
# 13171  [friday, vibes, in, the, http//tco/jumvlqegnl,...
# 13172  [its, here, shop, the, newest, http//tco/iwbzm...
# 13173  [get, the, perfect, layering, tee, for, only, ...
# 13174  [thursday, jewels, http//tco/xziuqgsivd, http/...
#
#                                           Part-of-Speech
# 0      [(the, DT), (always, RB), (on, IN), (icon, JJ)...
# 1      [(our, PRP$), (softest, JJS), (sweats, NN), (e...
# 2      [(layer, NN), (on, IN), (a, DT), (sweatshirt, ...
# 3      [(yes, RB), (you, PRP), (can, MD), (wear, VB),...
# 4      [(how, WRB), (to, TO), (take, VB), (your, PRP$...
# 5      [(universally, RB), (flattering, VBG), (high, ...
# 6      [(borrowed, VBN), (from, IN), (the, DT), (boys...
# 7      [(work, NN), (to, TO), (weekend, NN), (to, TO)...
# 8      [(this, DT), (is, VBZ), (our, PRP$), (bestsell...
# 9      [(whats, NNS), (your, PRP$), (favorite, JJ), (...
# 10     [(new, JJ), (authentic, JJ), (vintage, NN), (w...
# 11     [(our, PRP$), (soft, JJ), (valentine’s, NNS), ...
# 12     [(real, JJ), (love, NN), (starts, VBZ), (with,...
# 13     [(we, PRP), (love, VBP), (writer, JJ), (wife, ...
# 14     [(from, IN), (the, DT), (classic, JJ), (straig...
# 15     [(fits, NNS), (for, IN), (all, DT), (washes, N...
# 16     [(we, PRP), (make, VBP), (great, JJ), (jeans, ...
# 17     [(your, PRP$), (gap, NN), (act, NN), (was, VBD...
# 18     [(the, DT), (best, JJS), (sports, NNS), (bras,...
# 19     [(for, IN), (all, PDT), (the, DT), (ways, NNS)...
# 20     [(whether, IN), (youre, NN), (hitting, VBG), (...
# 21     [(make, VB), (your, PRP$), (move, NN), (in, IN...
# 22     [(start, VB), (the, DT), (year, NN), (off, RB)...
# 23     [(fits, NNS), (for, IN), (every, DT), (body, N...
# 24     [(sale, NN), (ends, VBZ), (soon, RB), (don’t, ...
# 25     [(the, DT), (great, JJ), (gap, NN), (sale, NN)...
# 26     [(it’s, VB), (our, PRP$), (biggest, JJS), (sal...
# 27     [(got, VBD), (last, JJ), (minute, JJ), (gifts,...
# 28     [(give, VB), (them, PRP), (what, WP), (they, P...
# 29     [(last, JJ), (call, NN), (for, IN), (great, JJ...
# ...                                                  ...
# 13145  [(vintage, NN), (throwback, NN), (tees, NNS), ...
# 13146  [(pick, VB), (your, PRP$), (fave, NN), (for, I...
# 13147     [(how, WRB), (http//tco/zh, JJ), (aewkyx, NN)]
# 13148  [(have, VB), (a, DT), (student, NN), (id, NN),...
# 13149  [(the, DT), (perfect, JJ), (back, NN), (to, TO...
# 13150  [(top, JJ), (bun, NN), (kinda, VBD), (day, NN)...
# 13151  [(keeping, VBG), (it, PRP), (casual, JJ), (htt...
# 13152  [(polo, NN), (perfection, NN), (get, VB), (the...
# 13153  [(ready, JJ), (for, IN), (cozy, JJ), (fall, NN...
# 13154  [(loving, VBG), (find, VB), (them, PRP), (in, ...
# 13155  [(class, NN), (it, PRP), (up, RP), (vintage, N...
# 13156  [(back, RB), (to, TO), (school, NN), (ready, N...
# 13157  [(when, WRB), (nobody, NN), (responds, VBZ), (...
# 13158  [(nature, NN), (girl, NN), (http//tco/i, NN), ...
# 13159  [(new, JJ), (arrivals, NNS), (are, VBP), (in, ...
# 13160  [(while, IN), (supplies, NNS), (last, JJ), (ge...
# 13161  [(find, VB), (your, PRP$), (perfect, JJ), (pol...
# 13162  [(our, PRP$), (cozy, NN), (waffle, NN), (henle...
# 13163  [(saturday, RB), (night, NN), (out, RP), (in, ...
# 13164  [(big, JJ), (city, NN), (dreams, NNS), (http//...
# 13165  [(layer, NN), (up, RP), (in, IN), (the, DT), (...
# 13166  [(buy, VB), (any, DT), (seriously, RB), (stret...
# 13167  [(meet, VB), (our, PRP$), (newest, JJS), (obse...
# 13168  [(score, RB), (our, PRP$), (fave, NN), (layeri...
# 13169  [(when, WRB), (you, PRP), (eat, VBP), (too, RB...
# 13170  [(seriously, RB), (soft, JJ), (seriously, RB),...
# 13171  [(friday, JJ), (vibes, NNS), (in, IN), (the, D...
# 13172  [(its, PRP$), (here, RB), (shop, VBZ), (the, D...
# 13173  [(get, VB), (the, DT), (perfect, JJ), (layerin...
# 13174  [(thursday, JJ), (jewels, NNS), (http//tco/xzi...
#
# [13175 rows x 7 columns]

# %%
from gensim.scripts.glove2word2vec import glove2word2vec
filename = "./glove.twitter.27B/glove.twitter.27B.50d.txt"
glove2word2vec(glove_input_file=filename, word2vec_output_file="gensim_glove_vectors.txt")

from gensim.models.keyedvectors import KeyedVectors
glove_model = KeyedVectors.load_word2vec_format("gensim_glove_vectors.txt", binary=False)
words = list(glove_model.wv.vocab)
# Out:
# /Users/anilvadali/.pyenv/versions/anaconda3-4.1.1/lib/python3.5/site-packages/ipykernel/__main__.py:7: DeprecationWarning: Call to deprecated `wv` (Attribute will be removed in 4.0.0, use self instead).

# %%
nounsNadj = []
counter = 0
for wordlist in tweetDF["Part-of-Speech"]:
    nas = [word.lower() for word,pos in wordlist if pos.startswith("NN") or pos.startswith("JJ")] 
    
    if len(nas) >= 3:
        keywords = random.sample(nas, 3)
    elif len(nas) >= 0 and len(tweetDF["List of Words"][counter]) > 0:
        sample = random.sample(tweetDF["List of Words"][counter],1)
        keywords = [word.lower() for word in sample]
    nounsNadj.append(keywords)
    counter += 1
    

tweetDF["Keywords"] = nounsNadj
print(tweetDF["Baseline"][463])
tweetDF
# Out:
# #relationshipgoals
#                                                 Baseline  \
# 0      The always-on Icon denim jacket, now in new wa...
# 1      Our softest sweats ever. An easy vintage vibe ...
# 2      Layer on a sweatshirt and a wear-everywhere Ic...
# 3      Yes, you can wear white denim year-round! Our ...
# 4      How to take your denim game to the next level:...
# 5      Universally flattering high waist. Made to hit...
# 6      Borrowed from the boys. Here’s how to wear our...
# 7      Work to weekend to whatever you've got going o...
# 8      This is our bestselling Slim, in new authentic...
# 9      What's your favorite way to wear #GapDenim: li...
# 10     New Authentic Vintage. Washes inspired by our ...
# 11     Our soft Valentine’s Day tee and Stretch Cotto...
# 12     "Real love starts with self-love." - %%USER%%,...
# 13     We LOVE writer, wife, mother, and host of #The...
# 14     From the classic Straight to bestselling High ...
# 15     Fits for all. Washes the way you like them. Je...
# 16     We make great jeans. You make them yours. Get ...
# 17     Your GAP ACT was 💯, Amy! We’d buy t-shirts fro...
# 18     The best sports bras by any stretch. Find your...
# 19     For all the ways you lounge, move, live. Get i...
# 20     Whether you're hitting the fitness studio or t...
# 21     Make your move in high rise leggings with Scul...
# 22     Start the year off right with the best legging...
# 23     Fits for every body and all the ways you move....
# 24     Sale. Ends. Soon. Don’t miss out on up to 75% ...
# 25     The Great Gap Sale continues! Get up to 75% of...
# 26     It’s our biggest sale of the year! Shop now &a...
# 27     Got last-minute gifts to buy? We’ve got you! G...
# 28     Give them what they want. Give GiftCards (in s...
# 29     Last call for great gifts for all! Shop by 3 p...
# ...                                                  ...
# 13145  vintage throwback tees are back &amp; we've ad...
# 13146  pick your fave for only $8! http://t.co/s9wttf...
# 13147  how #PLL should have ended... 😂 http://t.co/zh...
# 13148  have a student ID? show in store to get 10% of...
# 13149  the perfect back to school polos are now only ...
# 13150  top bun kinda day. http://t.co/vpUQQMigZg http...
# 13151  keeping it casual. http://t.co/K2I6CgySdm http...
# 13152  polo perfection. get them now for only $11. ht...
# 13153  ready for cozy fall days. 🍂 http://t.co/A66ri0...
# 13154  loving %%USER%%! find them in store &amp; onli...
# 13155  class it up. vintage-cut throwback polos are $...
# 13156  back to school ready in the perfect polo. http...
# 13157  when nobody responds to you in the group chat....
# 13158  nature girl. http://t.co/I07PuNl76g http://t.c...
# 13159  new arrivals are in store &amp; online today! ...
# 13160  while supplies last: get a free beanie with an...
# 13161  find your perfect polo for only $8! http://t.c...
# 13162  our cozy waffle henleys are now only $12! http...
# 13163  saturday night out in our fave %%USER%%! http:...
# 13164  big city dreams. http://t.co/K2ikCOZHRL http:/...
# 13165  layer up in the perfect baseball tee. find the...
# 13166  buy any seriously stretchy denim this weekend ...
# 13167  meet our newest obsession #tokyodarling. click...
# 13168  score our fave layering tees for only $12! cli...
# 13169  when you eat too much dinner... http://t.co/Di...
# 13170  seriously soft. seriously stretchy. seriously ...
# 13171  friday vibes in the #bethanymotacollection. ht...
# 13172  it's here: shop the newest #bethanymotacollect...
# 13173  get the perfect layering tee for only $12! htt...
#
#                                     List of Words + Punc  \
# 0      [The, always-on, Icon, denim, jacket, ,, now, ...
# 1      [Our, softest, sweats, ever, ., An, easy, vint...
# 2      [Layer, on, a, sweatshirt, and, a, wear-everyw...
# 3      [Yes, ,, you, can, wear, white, denim, year-ro...
# 4      [How, to, take, your, denim, game, to, the, ne...
# 5      [Universally, flattering, high, waist, ., Made...
# 6      [Borrowed, from, the, boys, ., Here, ’, s, how...
# 7      [Work, to, weekend, to, whatever, you've, got,...
# 8      [This, is, our, bestselling, Slim, ,, in, new,...
# 9      [What's, your, favorite, way, to, wear, %%, HA...
# 10     [New, Authentic, Vintage, ., Washes, inspired,...
# 11     [Our, soft, Valentine, ’, s, Day, tee, and, St...
# 12     [", Real, love, starts, with, self-love, .", -...
# 13     [We, LOVE, writer, ,, wife, ,, mother, ,, and,...
# 14     [From, the, classic, Straight, to, bestselling...
# 15     [Fits, for, all, ., Washes, the, way, you, lik...
# 16     [We, make, great, jeans, ., You, make, them, y...
# 17     [Your, GAP, ACT, was, 💯,, Amy, !, We, ’, d, bu...
# 18     [The, best, sports, bras, by, any, stretch, .,...
# 19     [For, all, the, ways, you, lounge, ,, move, ,,...
# 20     [Whether, you're, hitting, the, fitness, studi...
# 21     [Make, your, move, in, high, rise, leggings, w...
# 22     [Start, the, year, off, right, with, the, best...
# 23     [Fits, for, every, body, and, all, the, ways, ...
# 24     [Sale, ., Ends, ., Soon, ., Don, ’, t, miss, o...
# 25     [The, Great, Gap, Sale, continues, !, Get, up,...
# 26     [It, ’, s, our, biggest, sale, of, the, year, ...
# 27     [Got, last-minute, gifts, to, buy, ?, We, ’, v...
# 28     [Give, them, what, they, want, ., Give, GiftCa...
# 29     [Last, call, for, great, gifts, for, all, !, S...
# ...                                                  ...
# 13145  [vintage, throwback, tees, are, back, &, amp, ...
# 13146  [pick, your, fave, for, only, $8, !, http, :, ...
# 13147  [how, %%, HASHTAG, %%..., 😂, http, :, //t, ., ...
# 13148  [have, a, student, ID, ?, show, in, store, to,...
# 13149  [the, perfect, back, to, school, polos, are, n...
# 13150  [top, bun, kinda, day, ., http, :, //t, ., co/...
# 13151  [keeping, it, casual, ., http, :, //t, ., co/K...
# 13152  [polo, perfection, ., get, them, now, for, onl...
# 13153  [ready, for, cozy, fall, days, ., 🍂, http, :, ...
# 13154  [loving, %%, USER, %%!, find, them, in, store,...
# 13155  [class, it, up, ., vintage-cut, throwback, pol...
# 13156  [back, to, school, ready, in, the, perfect, po...
# 13157  [when, nobody, responds, to, you, in, the, gro...
# 13158  [nature, girl, ., http, :, //t, ., co/I07PuNl7...
# 13159  [new, arrivals, are, in, store, &, amp, ;, onl...
# 13160  [while, supplies, last, :, get, a, free, beani...
# 13161  [find, your, perfect, polo, for, only, $8, !, ...
# 13162  [our, cozy, waffle, henleys, are, now, only, $...
# 13163  [saturday, night, out, in, our, fave, %%, USER...
# 13164  [big, city, dreams, ., http, :, //t, ., co/K2i...
# 13165  [layer, up, in, the, perfect, baseball, tee, ....
# 13166  [buy, any, seriously, stretchy, denim, this, w...
# 13167  [meet, our, newest, obsession, %%, HASHTAG, %%...
# 13172  its here shop the newest HASHTAG http//tco/iwB...
# 13173  get the perfect layering tee for only    http/...
# 13174  thursday jewels  http//tco/XZiuQgSivd http//tc...
#
#                                            List of Words  \
# 0      [the, always, on, icon, denim, jacket, now, in...
# 1      [our, softest, sweats, ever, an, easy, vintage...
# 2      [layer, on, a, sweatshirt, and, a, wear, every...
# 3      [yes, you, can, wear, white, denim, year, roun...
# 4      [how, to, take, your, denim, game, to, the, ne...
# 5      [universally, flattering, high, waist, made, t...
# 6      [borrowed, from, the, boys, here’s, how, to, w...
# 7      [work, to, weekend, to, whatever, youve, got, ...
# 8      [this, is, our, bestselling, slim, in, new, au...
# 9      [whats, your, favorite, way, to, wear, light, ...
# 10     [new, authentic, vintage, washes, inspired, by...
# 11     [our, soft, valentine’s, day, tee, and, stretc...
# 12     [real, love, starts, with, self, love, writer,...
# 13     [we, love, writer, wife, mother, and, host, of...
# 14     [from, the, classic, straight, to, bestselling...
# 15     [fits, for, all, washes, the, way, you, like, ...
# 16     [we, make, great, jeans, you, make, them, your...
# 17     [your, gap, act, was, amy, we’d, buy, t, shirt...
# 18     [the, best, sports, bras, by, any, stretch, fi...
# 19     [for, all, the, ways, you, lounge, move, live,...
# 20     [whether, youre, hitting, the, fitness, studio...
# 21     [make, your, move, in, high, rise, leggings, w...
# 22     [start, the, year, off, right, with, the, best...
# 23     [fits, for, every, body, and, all, the, ways, ...
# 24     [sale, ends, soon, don’t, miss, out, on, up, t...
# 25     [the, great, gap, sale, continues, get, up, to...
# 26     [it’s, our, biggest, sale, of, the, year, shop...
# 27     [got, last, minute, gifts, to, buy, we’ve, got...
# 28     [give, them, what, they, want, give, giftcards...
# 29     [last, call, for, great, gifts, for, all, shop...
# ...                                                  ...
# 13145  [vintage, throwback, tees, are, back, &amp, we...
# 13146  [pick, your, fave, for, only, http//tco/s, wtt...
# 13147                        [how, http//tco/zh, aewkyx]
# 13148  [have, a, student, id, show, in, store, to, ge...
# 13149  [the, perfect, back, to, school, polos, are, n...
# 13150  [top, bun, kinda, day, http//tco/vpuqqmigzg, h...
# 13151  [keeping, it, casual, http//tco/k, i, cgysdm, ...
# 13152  [polo, perfection, get, them, now, for, only, ...
# 13153  [ready, for, cozy, fall, days, http//tco/a, ri...
# 13154  [loving, find, them, in, store, &amp, online, ...
# 13155  [class, it, up, vintage, cut, throwback, polos...
# 13156  [back, to, school, ready, in, the, perfect, po...
# 13157  [when, nobody, responds, to, you, in, the, gro...
# 13158  [nature, girl, http//tco/i, punl, g, http//tco...
# 13159  [new, arrivals, are, in, store, &amp, online, ...
# 13160  [while, supplies, last, get, a, free, beanie, ...
# 13161  [find, your, perfect, polo, for, only, http//t...
# 13162  [our, cozy, waffle, henleys, are, now, only, h...
# 13163  [saturday, night, out, in, our, fave, http//tc...
# 13164  [big, city, dreams, http//tco/k, ikcozhrl, htt...
# 13165  [layer, up, in, the, perfect, baseball, tee, f...
# 13166  [buy, any, seriously, stretchy, denim, this, w...
# 13167  [meet, our, newest, obsession, click, to, shop...
# 13168  [score, our, fave, layering, tees, for, only, ...
# 13169  [when, you, eat, too, much, dinner, http//tco/...
# 13170  [seriously, soft, seriously, stretchy, serious...
# 13171  [friday, vibes, in, the, http//tco/jumvlqegnl,...
# 13172  [its, here, shop, the, newest, http//tco/iwbzm...
# 13173  [get, the, perfect, layering, tee, for, only, ...
# 13174  [thursday, jewels, http//tco/xziuqgsivd, http/...
#
#                                           Part-of-Speech  \
# 0      [(the, DT), (always, RB), (on, IN), (icon, JJ)...
# 1      [(our, PRP$), (softest, JJS), (sweats, NN), (e...
# 2      [(layer, NN), (on, IN), (a, DT), (sweatshirt, ...
# 3      [(yes, RB), (you, PRP), (can, MD), (wear, VB),...
# 4      [(how, WRB), (to, TO), (take, VB), (your, PRP$...
# 5      [(universally, RB), (flattering, VBG), (high, ...
# 6      [(borrowed, VBN), (from, IN), (the, DT), (boys...
# 7      [(work, NN), (to, TO), (weekend, NN), (to, TO)...
# 8      [(this, DT), (is, VBZ), (our, PRP$), (bestsell...
# 9      [(whats, NNS), (your, PRP$), (favorite, JJ), (...
# 10     [(new, JJ), (authentic, JJ), (vintage, NN), (w...
# 11     [(our, PRP$), (soft, JJ), (valentine’s, NNS), ...
# 12     [(real, JJ), (love, NN), (starts, VBZ), (with,...
# 13     [(we, PRP), (love, VBP), (writer, JJ), (wife, ...
# 14     [(from, IN), (the, DT), (classic, JJ), (straig...
# 15     [(fits, NNS), (for, IN), (all, DT), (washes, N...
# 16     [(we, PRP), (make, VBP), (great, JJ), (jeans, ...
# 17     [(your, PRP$), (gap, NN), (act, NN), (was, VBD...
# 18     [(the, DT), (best, JJS), (sports, NNS), (bras,...
# 19     [(for, IN), (all, PDT), (the, DT), (ways, NNS)...
# 20     [(whether, IN), (youre, NN), (hitting, VBG), (...
# 21     [(make, VB), (your, PRP$), (move, NN), (in, IN...
# 22     [(start, VB), (the, DT), (year, NN), (off, RB)...
# 23     [(fits, NNS), (for, IN), (every, DT), (body, N...
# 24     [(sale, NN), (ends, VBZ), (soon, RB), (don’t, ...
# 25     [(the, DT), (great, JJ), (gap, NN), (sale, NN)...
# 26     [(it’s, VB), (our, PRP$), (biggest, JJS), (sal...
# 27     [(got, VBD), (last, JJ), (minute, JJ), (gifts,...
# 28     [(give, VB), (them, PRP), (what, WP), (they, P...
# 29     [(last, JJ), (call, NN), (for, IN), (great, JJ...
# ...                                                  ...
# 13145  [(vintage, NN), (throwback, NN), (tees, NNS), ...
# 13146  [(pick, VB), (your, PRP$), (fave, NN), (for, I...
# 13147     [(how, WRB), (http//tco/zh, JJ), (aewkyx, NN)]
# 13148  [(have, VB), (a, DT), (student, NN), (id, NN),...
# 13149  [(the, DT), (perfect, JJ), (back, NN), (to, TO...
# 13150  [(top, JJ), (bun, NN), (kinda, VBD), (day, NN)...
# 13151  [(keeping, VBG), (it, PRP), (casual, JJ), (htt...
# 13152  [(polo, NN), (perfection, NN), (get, VB), (the...
# 13153  [(ready, JJ), (for, IN), (cozy, JJ), (fall, NN...
# 13154  [(loving, VBG), (find, VB), (them, PRP), (in, ...
# 13155  [(class, NN), (it, PRP), (up, RP), (vintage, N...
# 13156  [(back, RB), (to, TO), (school, NN), (ready, N...
# 13157  [(when, WRB), (nobody, NN), (responds, VBZ), (...
# 13158  [(nature, NN), (girl, NN), (http//tco/i, NN), ...
# 13159  [(new, JJ), (arrivals, NNS), (are, VBP), (in, ...
# 13160  [(while, IN), (supplies, NNS), (last, JJ), (ge...
# 13161  [(find, VB), (your, PRP$), (perfect, JJ), (pol...
# 13162  [(our, PRP$), (cozy, NN), (waffle, NN), (henle...
# 13163  [(saturday, RB), (night, NN), (out, RP), (in, ...
# 13164  [(big, JJ), (city, NN), (dreams, NNS), (http//...
# 13165  [(layer, NN), (up, RP), (in, IN), (the, DT), (...
# 13166  [(buy, VB), (any, DT), (seriously, RB), (stret...
# 13167  [(meet, VB), (our, PRP$), (newest, JJS), (obse...
# 13168  [(score, RB), (our, PRP$), (fave, NN), (layeri...
# 13169  [(when, WRB), (you, PRP), (eat, VBP), (too, RB...
# 13170  [(seriously, RB), (soft, JJ), (seriously, RB),...
# 13171  [(friday, JJ), (vibes, NNS), (in, IN), (the, D...
# 13172  [(its, PRP$), (here, RB), (shop, VBZ), (the, D...
# 13173  [(get, VB), (the, DT), (perfect, JJ), (layerin...
# 13174  [(thursday, JJ), (jewels, NNS), (http//tco/xzi...
#
#                                          Keywords
# 0                          [favorite, denim, new]
# 1                        [easy, colorful, sweats]
# 2                            [denim, shop, layer]
# 3                               [white, pop, top]
# 4                            [denim, shop, color]
# 5                        [waist, authentic, high]
# 6                       [pair, belt, personality]
# 7                            [jeans, work, youve]
# 8                    [slim, versatile, authentic]
# 9                           [weve, washes, denim]
# 10                       [denim, authentic, rise]
# 11                           [leg, perfect, soft]
# 12                           [mother, love, wife]
# 13                     [importance, love, mother]
# 14                           [rise, skinny, body]
# 15                             [fits, denim, let]
# 16                           [denim, jeans, body]
# 17                               [we’d, buy, day]
# 18                       [sports, best, favorite]
# 19                            [gapfit, get, live]
# 20                   [favorites, youre, leggings]
# 21                          [rise, support, move]
# 22                      [everything, year, right]
# 23                             [fits, ways, body]
# 24                  [markdowns, sale, everything]
# 25                      [markdowns, great, don’t]
# 26                      [biggest, purchase, shop]
# 27                          [minute, we’ve, last]
# 28                       [give, store, giftcards]
# 29                               [shop, great, /]
# ...                                           ...
# 13145                   [weve, throwback, styles]
# 13146             [xqvtos, http//tco/s, wttfxtvd]
# 13147                                    [aewkyx]
# 13148                     [id, purchase, student]
# 13149                    [back, http//tco/j, ggz]
# 13150                           [hxgul, bun, day]
# 13151              [http//tco/qq, i, http//tco/k]
# 13152                    [sda, http//tco/r, polo]
# 13153                           [fall, muxp, bzv]
# 13154               [z, online, http//tco/eknbkp]
# 13155             [polos, vintage, http//tco/aaz]
# 13156                    [wraagl, ready, perfect]
# 13157                          [c, nobody, group]
# 13158                      [g, punl, http//tco/i]
# 13159                     [arrivals, store, &amp]
# 13160                  [last, stretchy, supplies]
# 13161                               [u, gn, polo]
# 13162   [waffle, http//tco/qbymdzyscx, sgwrsnuww]
# 13163              [bnwsds, night, http//tco/kwa]
# 13164         [dreams, http//tco/kagigepuuc, big]
# 13165                       [store, &amp, online]
# 13166                    [weekend, stretchy, thq]
# 13167                          [w, newest, click]
# 13168      [http//tco/qody, layering, http//tco/]
# 13169                               [ol, much, v]
# 13170                         [click, jean, soft]
# 13171  [http//tco/ucku, http//tco/jumvlqegnl, zc]
# 13172                                       [the]
# 13173                         [tee, vqdphapsw, x]
# 13174                          [thursday, bre, n]
#
# [13175 rows x 8 columns]

# %%
#Encoding Matrix
word_vec_matrix = np.empty((0,50))
for tweet in tweetDF["Keywords"]:
    vector = np.zeros(50)
    for keyword in tweet:
        try:
            vector += glove_model[keyword]
        except:
            continue
    word_vec_matrix = np.vstack((word_vec_matrix,vector))

    
word_vec_matrix.shape
# Out:
# (13175, 50)

# %%
max_tweet_length = max(tweetDF['List of Words + Punc'].str.len())+2

# %%
#Decoding Input Dictionary

dinput_vec_matrix = np.zeros((word_vec_matrix.shape[0],max_tweet_length)).astype(int)
int_to_word = {0: "", 1: "[START]", 2: "[END]"}
word_to_int = {"": 0, "[START]": 1, "[END]": 2}
dict_counter = 3
row_counter = 0

for tweet in tweetDF["List of Words + Punc"]:
    vector = np.zeros(max_tweet_length)
    word_counter = 0
    tweet = ["[START]"] + tweet
    for word in tweet:
        if word not in word_to_int.keys():
            int_to_word[dict_counter] = word
            word_to_int[word] = dict_counter
            
            vector[word_counter] = dict_counter
            dict_counter += 1
            word_counter += 1
        else:
            vector[word_counter] = word_to_int[word]
            word_counter += 1
    
    dinput_vec_matrix[row_counter] = vector
    row_counter += 1

dinput_vec_matrix = dinput_vec_matrix.astype(int)
dinput_vec_matrix.shape
# Out:
# (13175, 70)

# %%
doutput_vec_matrix = np.zeros((dinput_vec_matrix.shape[0],max_tweet_length,len(word_to_int.keys())), dtype = int)
row_counter = 0

for tweet in tweetDF["List of Words + Punc"]:
    word_counter = 0
    tweet = tweet + ["[END]"]
    for word in tweet:
        doutput_vec_matrix[row_counter, word_counter, word_to_int[word]] = 1
        word_counter += 1

    row_counter += 1

doutput_vec_matrix.shape
# Out:
# (13175, 70, 14783)

# %%
result = glove_model.most_similar(positive=["jacket", "denim", "wear"], topn=10)
print(result)
# Out:
# [('boots', 0.912922203540802), ('shoes', 0.9040590524673462), ('pants', 0.8981727361679077), ('shirt', 0.8935474157333374), ('shirts', 0.8905469179153442), ('jeans', 0.889249324798584), ('coat', 0.88731449842453), ('socks', 0.8866130709648132), ('sweater', 0.8853822946548462), ('dress', 0.8818666338920593)]

# %%
from keras.models import Model
from keras.layers import Dense, Input, GRU
from keras.layers.embeddings import Embedding

word_dim = 50
num_tokens = len(word_to_int.keys())

# Define the layers
word_vec_input = Input(shape=(word_dim,))
decoder_inputs = Input(shape=(None,))
decoder_embed = Embedding(input_dim=num_tokens, output_dim=word_dim, mask_zero=True)
decoder_gru_1 = GRU(word_dim, return_sequences=True, return_state=False)
decoder_gru_2 = GRU(word_dim, return_sequences=True, return_state=True)
decoder_dense = Dense(num_tokens, activation='softmax')

# Connect the layers
embedded = decoder_embed(decoder_inputs)
gru_1_output = decoder_gru_1(embedded, initial_state=word_vec_input)
gru_2_output, state_h = decoder_gru_2(gru_1_output)
decoder_outputs = decoder_dense(gru_2_output)

# Define the model that will be used for training
training_model = Model([word_vec_input, decoder_inputs], decoder_outputs)

# %%
batch_size = 128
epochs = 100
#adam
training_model.compile(optimizer='rmsprop', loss='categorical_crossentropy')
training_model.fit([word_vec_matrix, dinput_vec_matrix], doutput_vec_matrix,
          batch_size=batch_size,
          epochs=epochs,
          validation_split=0.2)
# Out:
# Train on 10540 samples, validate on 2635 samples
# Epoch 1/100
#   384/10540 [>.............................] - ETA: 16:36 - loss: 9.5966
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-28-36cfa06695b4> in <module>()
#       6           batch_size=batch_size,
#       7           epochs=epochs,
# ----> 8           validation_split=0.2)
#
# /Users/anilvadali/.pyenv/versions/anaconda3-4.1.1/lib/python3.5/site-packages/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, **kwargs)
#    1037                                         initial_epoch=initial_epoch,
#    1038                                         steps_per_epoch=steps_per_epoch,
# -> 1039                                         validation_steps=validation_steps)
#    1040
#    1041     def evaluate(self, x=None, y=None,
#
# /Users/anilvadali/.pyenv/versions/anaconda3-4.1.1/lib/python3.5/site-packages/keras/engine/training_arrays.py in fit_loop(model, f, ins, out_labels, batch_size, epochs, verbose, callbacks, val_f, val_ins, shuffle, callback_metrics, initial_epoch, steps_per_epoch, validation_steps)
#     197                     ins_batch[i] = ins_batch[i].toarray()
#     198
# --> 199                 outs = f(ins_batch)
#     200                 outs = to_list(outs)
#     201                 for l, o in zip(out_labels, outs):
#
# /Users/anilvadali/.pyenv/versions/anaconda3-4.1.1/lib/python3.5/site-packages/keras/backend/tensorflow_backend.py in __call__(self, inputs)
#    2713                 return self._legacy_call(inputs)
#    2714
# -> 2715             return self._call(inputs)
#    2716         else:
#    2717             if py_any(is_tensor(x) for x in inputs):
#
# /Users/anilvadali/.pyenv/versions/anaconda3-4.1.1/lib/python3.5/site-packages/keras/backend/tensorflow_backend.py in _call(self, inputs)
#    2673             fetched = self._callable_fn(*array_vals, run_metadata=self.run_metadata)
#    2674         else:
# -> 2675             fetched = self._callable_fn(*array_vals)
#    2676         return fetched[:len(self.outputs)]
#    2677
#
# /Users/anilvadali/.pyenv/versions/anaconda3-4.1.1/lib/python3.5/site-packages/tensorflow/python/client/session.py in __call__(self, *args, **kwargs)
#    1437           ret = tf_session.TF_SessionRunCallable(
#    1438               self._session._session, self._handle, args, status,
# -> 1439               run_metadata_ptr)
#    1440         if run_metadata:
#    1441           proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# KeyboardInterrupt:

# %%
#training_model.save("basic.hdf5")
from keras.models import load_model
loaded_model=load_model('basic.hdf5')
loaded_model.compile(optimizer='rmsprop', loss='categorical_crossentropy')
loaded_model.
# Out:
# <bound method Network.load_weights of <keras.engine.training.Model object at 0x1ac7c0e908>>

# %%
# decoder_embed2 = Embedding(input_dim=num_tokens, output_dim=word_dim, mask_zero=True)
# embedded2 = decoder_embed2(decoder_inputs)
# gru_1_output2 = decoder_gru_1(embedded2, initial_state=word_vec_input)
# gru_2_output2, state_h2 = decoder_gru_2(gru_1_output2)
# decoder_outputs2 = decoder_dense(gru_2_output2)

# Also create a model for inference (this returns the GRU state)
decoder_model = Model([word_vec_input, decoder_inputs], [decoder_outputs, state_h])

# %%
def decode_sequence(input_seq):
    # Encode the input as state vectors.
    encoding_vector = np.zeros((1,50))
    for word in input_seq:
        try:
            encoding_vector[0] += glove_model[word]
        except:
            continue
    
#     print(encoding_vector.shape)
            
    target_seq = np.zeros((1,59), dtype=int)
    target_seq[0,0] = word_to_int["[START]"]
#     target_seq[0,1] = word_to_int["We"]
#     target_seq[0,2] = word_to_int["are"]
#     target_seq[0,3] = word_to_int[","]
    
#     print(len(target_seq))
    
    stop_condition = False
    decoded_sentence = ''
    counter = 1
    # Sampling loop for a batch of sequences
    # (to simplify, here we assume a batch of size 1).
    while not stop_condition:
        output_tokens, h= decoder_model.predict([encoding_vector, target_seq])
        
        # Sample a token
        sampled_token_index = np.argmax(output_tokens[0, -1, :])
        sampled_char = int_to_word[sampled_token_index]
        decoded_sentence += sampled_char + " "
        
        if (sampled_char == "[END]" or
           len(decoded_sentence.split()) > 37):
            stop_condition = True
        
#         next_word = np.zeros((1,59))
#         next_word[0, counter] = sampled_token_index
        target_seq[0, counter] = sampled_token_index
        counter+=1
    
    
    return decoded_sentence

# %%
# print(word_vec_matrix.shape)
# print(dinput_vec_matrix.shape)
# print('-----------')
print(decode_sequence(["denim"]))
print(decode_sequence(["warm", "cozy"]))
print(decode_sequence(["nice", "sun", "friday"]))
# Out:
# nicer buds saved potential parkas 🎸%% pairing oceanic Kye warmest System Christopher ...📢🙆 press essentials Remarkable Remarkable Forever brought brought tapped tapped falling tapped Blushing Blushing Blushing 50023705 50023705 rugby-inspired skirts paid Warmer 🚩 70s 70s Shoot Shoot
# nicer buds saved potential parkas 🎸%% pairing oceanic Kye warmest System Christopher ...📢🙆 press essentials Remarkable Remarkable Forever brought brought tapped tapped falling tapped Blushing Blushing Blushing 50023705 50023705 rugby-inspired skirts paid Warmer 🚩 70s 70s Shoot Shoot
# nicer buds saved potential parkas 🎸%% pairing oceanic Kye warmest System Christopher ...📢🙆 press essentials Remarkable Remarkable Forever brought brought tapped tapped falling tapped Blushing Blushing Blushing 50023705 50023705 rugby-inspired skirts paid Warmer 🚩 70s 70s Shoot Shoot
